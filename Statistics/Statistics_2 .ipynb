# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <font face = "Verdana" size = "4"> <b> Types of Distribution</b></font><br>
# <font face = "Verdana" size = "3">There are various types of distributions in statistics. But most commanly used distribution is normal distribution and Z distribution in our course
#
# <font face = "Verdana" size = "4"> <b>1) Normal Distribution</b></font><br>
# <font face = "Verdana" size = "3">A normal distribution is the proper term for a probability <mark> bell curve</mark>. In a normal distribution the mean is zero and the standard deviation is<br>
#     https://www.wallstreetmojo.com/normal-distribution/#normal-distribution-explanation

# %% [markdown]
# <img src="tod.png"  width="850" height="550">
# <hr>

# %% [markdown]
# <font face = "Verdana" size = "4"> <b> 2)Bernoulli Distribution</b>   This distribution deals with the data which only has <mark>1 trial & only 2 possible outcomes.</mark> Anything other than that will not fall under the Bernoulli Distribution category.</font><br>
# <img src="bree.png"  width="350" height="150">
#
# <font face = "Verdana" size = "3">Lets take real time Example <br>
#     <b>Problem statement :-</b> what is the probability of student !! passing and failed in exam or interview based on past data<br>
#
#
# <font face = "Verdana" size = "3">I am writing in exam there is two chance that either i pass or fail
# Suppose say i have trained 5000 student, and i documented there result
# Now in this batch i need to find out what is probably of pass or failed
# Suppose (x) student comes and what will be the probability of that student to pass or fail in the interview
#     <img src="br.png"  width="350" height="150">
#
# <font face = "Verdana" size = "3"> According to past data probability of passing is 70 % and fail 30%
#
# <font face = "Verdana" size = "3">
# Interpretation Example -<br>
# Student Result<br>
# X1------- Pass<br>
# X2------- Fail<br>
# X3------- Pass<br>
# X4------- Pass<br>
# X5------- Fail<br>
# X6------- Pass<br>
# X7------- ????? (probability of student will fail)<br>
# P(Success) = p <br>P(Failure)= 1-p<br>
# Let, X=1 when Success and X=0 when failure,

# %% [markdown]
# <font face = "Verdana" size = "3"><br>
# Then the probability distribution function is given as: for x= (0,1)<br>
# p(x) = [p^x] * [(1-p)^1-x] = p<br><hr>
# So, P(1) [p^1]* [(1-p) ^0] = p<br>
# P(0) = [P^0]*[(1-p)^1] = 1-p<br>
#     https://medium.com/swlh/binomial-vs-bernoulli-distribution-dd9197c418d

# %% [markdown]
# <hr>
# <font face = "Verdana" size = "4"> <b> 3) Binomial Distribution</b></font><br>
# <font face = "Verdana" size = "3">It is the collection of Bernoulli trials for the same event, i.e., it contains more than 1 Bernoulli event for the same scenario for which the Bernoulli trial is calculated.
#
# <font face = "Verdana" size = "3"> <b> Way to represent Binomial Distribution!</b><br>
#
# <font face = "Verdana" size = "3">
# It can be represented using two things:<br>
#
# <font face = "Verdana" size = "3">
# 1) The number of Bernoulli trials.<br>
# 2) Probability of an event in each trial.<br>
#     <img src="bino.png"  width="350" height="150">
# Here,<br>
# “n” = number of Bernoulli trials<br>
# “p” =  probability of the event in each trial<br>
# <hr>

# %% [markdown]
# <font face = "Verdana" size = "4"> <b>4) Uniform Distribution </b></font><br>
# <font face = "Verdana" size = "3"> Uniform distribution refers to a type of probability distribution in which all outcomes are equally likely.
#
# <font face = "Verdana" size = "3"> Example -
#     <mark>Deck of cards</mark> - Probability of getting any perticular shape and number (1/52)
#     <img src="https://media.istockphoto.com/vectors/isometric-deck-of-poker-cards-upside-down-and-one-card-suit-up-vector-id1273750059?k=20&m=1273750059&s=612x612&w=0&h=EvAXGuYFtu-UnQ_I6KfD-nSdbALw75oYxWncY4NCtWs="  width="150" height="150">
#
# <hr>

# %% [markdown]
# <font face = "Verdana" size = "5"> <b> Inferential Statistics.</b></font><br>
# <font face = "Verdana" size = "3">Sampling data and infer/ (तर्क करना /अनुमान करना) the result to describe entire population
#
# <font face = "Verdana" size = "4"><b>Central limit theorom</b></font><br>
#     What central limit theorom says !!<br>
#
# <font face = "Verdana" size = "3"> <b>1)  Normal distribution -</b> Distribution is always normal irrespective of sample size.<br>
#     if we Randomly pick some sample 10 or 100 or 1000  from normal distributed data and we plot that sample it will also look like normal distribution data <br>
#
# <font face = "Verdana" size = "3"> <b>2)Non-Normal distribution -</b> If sample size is adequate/(उचित) (appr > 30 sample), distribution starts looking normal.<br>
#     if we Randomly picked enough number sample (according to Central limit theorom appr > 30 sample ) from non_normal norm distributed data and we plot that sample it will also look like normal distribution data <br>
#     ![image-3.png](attachment:image-3.png)
#
#
# <font face = "Verdana" size = "4"><b> μX̄ = μ (Mean of sample mean = Population mean)</b></font><br>
# <img src="clt.png"  width="350" height="250">
#
#
# <font face = "Verdana" size = "4"><b> σx̅ = σ/√n (Population std / sqrt of sample size) </b></font><br>
#     ![image.png](attachment:image.png)
#     ![image-2.png](attachment:image-2.png)
# <hr>

# %% [markdown]
# <font face = "Verdana" size = "4"> <b>PDF, CDF </b></font><br>
# <font face = "Verdana" size = "3"> pdf = Probability Density Function<br>
# cdf = Cumulative density function<br>
# https://www.wallstreetmojo.com/normal-distribution/#normal-distribution-explanation
# <hr>

# %% [markdown]
# <font face = "Verdana" size = "3">Lets , take example a group of<b> 100 </b>people <b>traveling</b> from<b><mark> bangalore to mumbai</mark> </b>by there own car

# %% [markdown]
# <br>
#     <font face = "Verdana" size = "3">Now , every  one take different different hour to reach  mumbai
# Some will take 8 hour some will take 12 hours
# Hours [ 8, 12, 14, 16, 18, 20,]
#     <img src="pdf.png"  width="450" height="550">

# %% [markdown]
#  <font face = "Verdana" size = "3"> So Now , If i wanted to find probability suppose one  more person has come🚴🛣️ A new guy who wanted to travel  so  what will be the probability of that person
#     <img src="p(xperson).png"  width="450" height="550">

# %% [markdown]
#  <font face = "Verdana" size = "3"> Now, Let's say the person is taking 10 hour to reach the mumbai

# %% [markdown]
# <font face = "Verdana" size = "3"> So , the probability will be 0.4×100 = 40%
# Probability of X person  is 40% percent
# So here we are going to find probability of any occurring particular event
# So this about PDF

# %% [markdown]
# <font face = "Verdana" size = "3"> <b>Now , What about CDF,</b>

# %% [markdown]
# <img src="cdf.png"  width="450" height="550">

# %% [markdown]
# <font face = "Verdana" size = "3"> Any XYZ person reaching within  6 hour <br>
# So what is the probability of XYZ person reaching to mumbai within 6 hours <br>
# It can be 2 hours 5 hours 6 hours So the probability is 0.25 <br>
# Let's suppose i have to find between 8 to 10 hours <br>

# %% [markdown]
# <font face = "Verdana" size = "3"> <b> Note :- The probability of an event lies between <mark> 0 and 1 and start from 0

# %% [markdown]
# ## Next Day Agenda
# ### Practicle Examples

# %% [markdown]
# <table style="border-collapse: collapse; width: 100%; border: 1px solid #ccc; font-family: Verdana, sans-serif;">
#         <tbody>
#             <tr>
#                 <th style="border: 1px solid #ccc; padding: 10px; background-color: #f2f2f2; text-align: center;">No.</th>
#                 <th style="border: 1px solid #ccc; padding: 10px; background-color: #f2f2f2; text-align: center;">Examples</th>
#                 <th style="border: 1px solid #ccc; padding: 10px; background-color: #f2f2f2; text-align: center;">Using Test</th>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">1</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Whats is the probability of getting 50 marks?</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Z-test / cdf function</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">2</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Whats is the probability of getting marks between 50 to 60?</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Z-test / cdf function</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">3</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Car mileage / Average</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Z-test / left test</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">4</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Amazon new home delivery method reduces delivery time</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Z-test / right test</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">5</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Difference in car mileage when driven by two different persons</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Z-test / two-tail test</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">6</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Student test</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">T-test / one sample</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">7</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Student test</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">T-test / two sample / independent sample</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">8</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Student test</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">T-test / two sample / paired sample</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">9</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Reaction time in the morning after drinking various drinks</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Anova-test theory</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">10</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Semester marks</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Practical implementation of Anova test</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">11</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Goodness of fit sales expectation</td>
#                 <td style="border: 1px solid #ccc; padding: 10px; text-align: center;">Chi-squared test</td>
#             </tr>
#         </tbody>
#     </table>

# %% [markdown]
# <font face = "Verdana" size = "3"> <b> What is deffernce between Z-test vs T-test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font face = "Verdana" size = "3"> Some are use full links are given below to clear doubt on above topics
#     - https://youtu.be/PUBZC2MJ50Y
